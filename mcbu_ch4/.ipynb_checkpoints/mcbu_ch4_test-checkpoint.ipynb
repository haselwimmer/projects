# %% [markdown]
# # MCBU CH4 plumes data analysis

# %% [markdown]
# ## Import libraries

# %%
import os
import datetime as dt
import json

import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import arcgis
from arcgis.gis import GIS
from arcgis.features import GeoAccessor
import contextily as cx

#https://towardsdatascience.com/how-to-set-up-anaconda-and-jupyter-notebook-the-right-way-de3b7623ea4a

# %% [markdown]
# ## Connect to MapHub

# %%
gis = GIS("https://maphub-amer.tst.azure.chevron.com/portal", client_id='bb6vn14P957pN6bV')
print("Logged in as: " + gis.properties.user.username)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://maphub-amer.tst.azure.chevron.com/portal/sharing/rest//oauth2/authorize?response_type=code&client_id=bb6vn14P957pN6bV&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=YB0JdC8nDiwz8nW16AMSqfPsJI5oBl
# Enter code obtained on signing in using SAML: ········
# C:\Users\ekqo\Miniconda3\envs\arcgis\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'maphub-amer.tst.azure.chevron.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Logged in as: ekqo

# %% [markdown]
# ## Search for layers

# %%
# Search for Feature Layers owned by the logged-in user
my_content = gis.content.search(query="owner:" + gis.users.me.username, 
                                item_type="Feature Layer", 
                                max_items=15)

my_content
# Out:
# [<Item title:"SJVBU_BVLOS_staging" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"thailand_spill_jan_2022_aoi" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"CVX_ca_wells_active" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"CPP_SJVBU_BVLOS_observations" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"Fall 2021 Plumes detected by GAO - Carbon Mapper" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"Fall_2021_Sources" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"COMM_MCBU_OPS_FOT_OUTLINE" type:Feature Layer Collection owner:ekqo>,
#  <Item title:"Angola offshore platforms" type:Feature Layer Collection owner:ekqo>]

# %% [markdown]
# ## Access group and show contents

# %%
ch4_mcbu_group = gis.groups.search('title:MCBU_CH4', max_groups=15)
ch4_mcbu_group = ch4_mcbu_group[0]
gis.groups.get(ch4_mcbu_group.groupid)

# %%
ch4_mcbu_group.content()

# %% [markdown]
# ## Load the plumes data into a gdf

# %%
# Plumes data title
title = 'Fall 2021 Plumes detected by GAO - Carbon Mapper'

# Search for the plumes data by title
plumes_id = gis.content.search(query='title:' + title,
                               item_type='Feature Layer',
                               max_items=1)

# Get the plumes data using the itemid
plumes_data = gis.content.get(plumes_id[0].itemid).layers[0]

# .query() returns a FeatureSet
fset = plumes_data.query()

# get a GeoJSON string representation of the FeatureSet
gjson_string = fset.to_geojson

# read GeoJSON string into a dict
gjson_dict = json.loads(gjson_string)

# Read the dict into a gdf
plumes_gdf = gpd.GeoDataFrame.from_features(gjson_dict['features'])

# Set the CRS
plumes_gdf = plumes_gdf.set_crs(epsg=3857)
plumes_gdf
# Out:
#                               geometry  OBJECTID  source_id  plume_lat  \
# 0    POINT (-11594403.640 3776182.850)      9827  F21P_0001  32.098010
# 1    POINT (-11590221.367 3782859.353)      9828  F21P_0002  32.148804
# 2    POINT (-11585571.552 3785645.330)      9829  F21P_0003  32.169991
# 3    POINT (-11575563.929 3793028.206)      9830  F21P_0004  32.226113
# 4    POINT (-11574385.056 3792413.955)      9831  F21P_0005  32.221445
# ..                                 ...       ...        ...        ...
# 768  POINT (-11510866.600 3730136.646)     10595  F21P_0457  31.746928
# 769  POINT (-11525399.137 3720740.354)     10596  F21P_0200  31.675121
# 770  POINT (-11515708.330 3726651.133)     10597  F21P_0340  31.720298
# 771  POINT (-11522960.349 3731529.430)     10598  F21P_0194  31.757567
# 772  POINT (-11526686.324 3726158.425)     10599  F21P_0195  31.716533
#
#       plume_lon         plume_candidate_id  date_of_detection  \
# 0   -104.154300  GAO20211003t155009p0000-A      1633219200000
# 1   -104.116730  GAO20211003t155009p0000-B      1633219200000
# 2   -104.074960  GAO20211003t155009p0000-C      1633219200000
# 3   -103.985060  GAO20211003t155009p0000-D      1633219200000
# 4   -103.974470  GAO20211003t155009p0000-E      1633219200000
# ..          ...                        ...                ...
# 768 -103.403874  GAO20211017t181626p0000-A      1634428800000
# 769 -103.534422  GAO20211017t181626p0000-B      1634428800000
# 770 -103.447368  GAO20211017t181626p0000-C      1634428800000
# 771 -103.512514  GAO20211017t183345p0000-A      1634428800000
# 772 -103.545985  GAO20211017t183345p0000-B      1634428800000
#
#     time_of_detection source_type     source_type_label  \
# 0            15:50:09        well            Production
# 1            15:50:09        tank            Production
# 2            15:50:09  compressor  Gathering & Boosting
# 3            15:50:09  compressor  Gathering & Boosting
# 4            15:50:09  compressor  Gathering & Boosting
# ..                ...         ...                   ...
# 768          18:16:26     unknown                  None
# 769          18:16:26        tank            Production
# 770          18:16:26        well            Production
# 771          18:33:45  processing            Processing
# 772          18:33:45        well            Production
#
#                       ipcc      qplume  sigma_qplume active_flare  \
# 0    1B2 Oil & Natural Gas  237.703647     70.335432         None
# 1    1B2 Oil & Natural Gas  488.323421    223.227806         None
# 2    1B2 Oil & Natural Gas  582.313511    172.122195         None
# 3    1B2 Oil & Natural Gas  720.878562    199.999978         None
# 4    1B2 Oil & Natural Gas  666.558008    262.897112         None
# ..                     ...         ...           ...          ...
# 768  1B2 Oil & Natural Gas  177.910257     98.995010         None
# 769  1B2 Oil & Natural Gas  222.816707     47.896354         None
# 770  1B2 Oil & Natural Gas  250.746178     60.359406         None
# 771  1B2 Oil & Natural Gas  217.586591     75.081864         None
# 772  1B2 Oil & Natural Gas  201.409493     72.794419         None
#
#     inactive_flare                Operator_Alias  \
# 0             None                   CHEVRON USA
# 1             None  OCCIDENTAL PETROLEUM COMPANY
# 2             None             SENDERO MIDSTREAM
# 3             None        DCP MIDSTREAM PARTNERS
# 4             None           ENTERPRISE PRODUCTS
# ..             ...                           ...
# 768           None                       UNKNOWN
# 769           None        DIAMONDBACK ENERGY INC
# 770           None  OCCIDENTAL PETROLEUM COMPANY
# 771           None                        ENLINK
# 772           None             ROYAL DUTCH SHELL
#
#                                               imageurl  County       State
# 0    https://edf-permian-data.s3.amazonaws.com/imag...    Eddy  New Mexico
# 1    https://edf-permian-data.s3.amazonaws.com/imag...    Eddy  New Mexico
# 2    https://edf-permian-data.s3.amazonaws.com/imag...    Eddy  New Mexico
# 3    https://edf-permian-data.s3.amazonaws.com/imag...    Eddy  New Mexico
# 4    https://edf-permian-data.s3.amazonaws.com/imag...    Eddy  New Mexico
# ..                                                 ...     ...         ...
# 768  https://edf-permian-data.s3.amazonaws.com/imag...  Loving       Texas
# 769  https://edf-permian-data.s3.amazonaws.com/imag...  Loving       Texas
# 770  https://edf-permian-data.s3.amazonaws.com/imag...  Loving       Texas
# 771  https://edf-permian-data.s3.amazonaws.com/imag...  Loving       Texas
# 772  https://edf-permian-data.s3.amazonaws.com/imag...  Loving       Texas
#
# [773 rows x 19 columns]

# %% [markdown]
# ## Load the field outlines into a gdf

# %%
# Title for fields data
title = 'COMM_MCBU_OPS_FOT_OUTLINE'

# Search for the plumes data by title
fields_id = gis.content.search(query='title:' + title,
                               item_type='Feature Layer',
                               max_items=35)

# Get the plumes data using the itemid
fields_data = gis.content.get(fields_id[0].itemid).layers[0]

# .query() returns a FeatureSet
fset = fields_data.query()

# get a GeoJSON string representation of the FeatureSet
gjson_string = fset.to_geojson

# read GeoJSON string into a dict
gjson_dict = json.loads(gjson_string)

# Read the dict into a gdf
fields_gdf = gpd.GeoDataFrame.from_features(gjson_dict['features'])

# Set the CRS
fields_gdf = fields_gdf.set_crs(epsg=4267)

# Reproject
fields_gdf = fields_gdf.to_crs(epsg=3857)
fields_gdf
# Out:
#                                               geometry  OBJECTID  \
# 0    POLYGON ((-11502569.886 3663379.551, -11504181...      2021
# 1    POLYGON ((-11370448.719 3754158.035, -11370448...      2022
# 2    POLYGON ((-11349502.349 3714360.021, -11351113...      2023
# 3    POLYGON ((-11355947.446 3742773.918, -11355947...      2024
# 4    POLYGON ((-11317278.436 3786473.139, -11315667...      2025
# ..                                                 ...       ...
# 147  POLYGON ((-11500909.460 3776943.393, -11502520...      2168
# 148  POLYGON ((-11554082.266 3859009.447, -11554082...      2169
# 149  POLYGON ((-11554082.325 3860924.724, -11555693...      2170
# 150  POLYGON ((-11550859.769 3855179.839, -11552470...      2171
# 151  POLYGON ((-11537890.963 3861769.040, -11537901...      2172
#
#          AREA_NAME FIELD_OPERATION_TEAM_NAME PRODUCTION_TEAM_NAME FIELD_CODE  \
# 0     CENTRAL AREA                     TEXAS          FT STOCKTON   UCS-QV2H
# 1    MIDLAND BASIN                    ODESSA       ODESSA CENTRAL   UCS-PF8H
# 2    MIDLAND BASIN                    ODESSA       ODESSA CENTRAL    UCS-QP5
# 3    MIDLAND BASIN                    ODESSA          ODESSA EAST   UCS-QP5H
# 4    MIDLAND BASIN                    ODESSA          ODESSA EAST    UCS-QX1
# ..             ...                       ...                  ...        ...
# 147   CENTRAL AREA   PERMIAN CO2 WATERFLOODS                HOBBS    UCS-LG9
# 148   CENTRAL AREA   PERMIAN CO2 WATERFLOODS                HOBBS    UCS-RK1
# 149   CENTRAL AREA   PERMIAN CO2 WATERFLOODS                HOBBS    UCS-EB7
# 150   CENTRAL AREA   PERMIAN CO2 WATERFLOODS                HOBBS    UCS-KP5
# 151   CENTRAL AREA   PERMIAN CO2 WATERFLOODS                HOBBS    UCS-V06
#
#                     FIELD_NAME MCBU_GIS_DATA_SOURCE_TYPE  \
# 0    WOLFBONE (TX) HZ (REEVES)                     EXCEL
# 1       BRYANT -G- HORIZONTALS                     EXCEL
# 2             SPRAYBERRY TREND                     EXCEL
# 3    SPRAYBERRY TREND - CMC HZ                     EXCEL
# 4      SPRAYBERRY TREND VIOLET                     EXCEL
# ..                         ...                       ...
# 147                    WILDCAT                     EXCEL
# 148                      YOUNG                     EXCEL
# 149                YOUNG NORTH                     EXCEL
# 150                YOUNG SOUTH                     EXCEL
# 151          MESCALERO ESCARPE                     EXCEL
#
#                 MCBU_GIS_SOURCE_NAME  MCBU_GIS_DATA_RECEIVED_DATE  \
# 0    MCBU Production Reporting (MPR)                1631664000000
# 1    MCBU Production Reporting (MPR)                1631664000000
# 2    MCBU Production Reporting (MPR)                1631664000000
# 3    MCBU Production Reporting (MPR)                1631664000000
# 4    MCBU Production Reporting (MPR)                1631664000000
# ..                               ...                          ...
# 147  MCBU Production Reporting (MPR)                1631664000000
# 148  MCBU Production Reporting (MPR)                1631664000000
# 149  MCBU Production Reporting (MPR)                1631664000000
# 150  MCBU Production Reporting (MPR)                1631664000000
# 151  MCBU Production Reporting (MPR)                1631664000000
#
#      MCBU_GIS_DATA_UPLOADED_DATE  MCBU_GIS_DATA_MODIFIED_DATE  \
# 0                  1632096000000                1632096000000
# 1                  1632096000000                1632096000000
# 2                  1632096000000                1632096000000
# 3                  1632096000000                1632096000000
# 4                  1632096000000                1632096000000
# ..                           ...                          ...
# 147                1635724800000                1635724800000
# 148                1635724800000                1635724800000
# 149                1635724800000                1635724800000
# 150                1635724800000                1635724800000
# 151                1635724800000                1635724800000
#
#     MCBU_GIS_DATA_MODIFIED_BY MCBU_GIS_DATA_REMARK CURRENT_INDICATOR_LF  \
# 0        Janice Fisher (KCVL)                 None                    Y
# 1        Janice Fisher (KCVL)                 None                    Y
# 2        Janice Fisher (KCVL)                 None                    Y
# 3        Janice Fisher (KCVL)                 None                    Y
# 4        Janice Fisher (KCVL)                 None                    Y
# ..                        ...                  ...                  ...
# 147      Janice Fisher (KCVL)                 None                    Y
# 148      Janice Fisher (KCVL)                 None                    Y
# 149      Janice Fisher (KCVL)                 None                    Y
# 150      Janice Fisher (KCVL)                 None                    Y
# 151      Janice Fisher (KCVL)                                         Y
#
#     MCBU_GIS_OPS_CONTACT  SHAPE.STArea()  SHAPE.STLength()
# 0       Jennifer Pinnick        0.002304          0.492089
# 1          Matt Anderson        0.003142          0.578932
# 2          Matt Anderson        0.001676          0.231572
# 3          Matt Anderson        0.002304          0.405253
# 4          Matt Anderson        0.000628          0.144732
# ..                   ...             ...               ...
# 147     Jennifer Pinnick        0.000628          0.173679
# 148     Jennifer Pinnick        0.000419          0.115786
# 149     Jennifer Pinnick        0.000209          0.057893
# 150     Jennifer Pinnick        0.000209          0.057893
# 151     Jennifer Pinnick        0.000250          0.063538
#
# [152 rows x 18 columns]

# %% [markdown]
# ## Clip plumes to field outlines

# %%
plumes_gdf_clipped = gpd.clip(fields_gdf, plumes_gdf)
plumes_gdf_clipped.drop(columns=['MCBU_GIS_DATA_REMARK'], inplace=True)
plumes_gdf_clipped.shape
# Out:
# (10, 17)

# %% [markdown]
# ## Export clipped plumes to feature layer

# %%
# Convert gdf to sedf
plumes_sedf_clipped = GeoAccessor.from_geodataframe(plumes_gdf_clipped, inplace=False, column_name='SHAPE')
plumes_sedf_clipped
# Out:
#      OBJECTID       AREA_NAME FIELD_OPERATION_TEAM_NAME PRODUCTION_TEAM_NAME  \
# 2        2023   MIDLAND BASIN                    ODESSA       ODESSA CENTRAL
# 3        2024   MIDLAND BASIN                    ODESSA          ODESSA EAST
# 10       2031   MIDLAND BASIN                    ODESSA          ODESSA WEST
# 78       2099  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 98       2119  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 83       2104  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 40       2061  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 100      2121  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 88       2109  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
# 94       2115  DELAWARE BASIN                  CARLSBAD        CARLSBAD EAST
#
#     FIELD_CODE                  FIELD_NAME MCBU_GIS_DATA_SOURCE_TYPE  \
# 2      UCS-QP5            SPRAYBERRY TREND                     EXCEL
# 3     UCS-QP5H   SPRAYBERRY TREND - CMC HZ                     EXCEL
# 10     UCS-PA1                FOUR CORNERS                     EXCEL
# 78     UCS-PK9  AVALON SOUTH (NM)  HZ (SD)                     EXCEL
# 98     UCS-LT5                   SALT DRAW                     EXCEL
# 83    UCS-EC7H            CULEBRA BLUFF HZ                     EXCEL
# 40     UCS-RI3             SAND DUNES WEST                     EXCEL
# 100    UCS-RK6                 TRISTE DRAW                     EXCEL
# 88     UCS-RE7                 INGLE WELLS                     EXCEL
# 94     UCS-RF8                  MESA VERDE                     EXCEL
#
#                 MCBU_GIS_SOURCE_NAME  MCBU_GIS_DATA_RECEIVED_DATE  \
# 2    MCBU Production Reporting (MPR)                1631664000000
# 3    MCBU Production Reporting (MPR)                1631664000000
# 10   MCBU Production Reporting (MPR)                1631664000000
# 78   MCBU Production Reporting (MPR)                1631664000000
# 98   MCBU Production Reporting (MPR)                1631664000000
# 83   MCBU Production Reporting (MPR)                1631664000000
# 40   MCBU Production Reporting (MPR)                1631664000000
# 100  MCBU Production Reporting (MPR)                1631664000000
# 88   MCBU Production Reporting (MPR)                1631664000000
# 94   MCBU Production Reporting (MPR)                1631664000000
#
#      MCBU_GIS_DATA_UPLOADED_DATE  MCBU_GIS_DATA_MODIFIED_DATE  \
# 2                  1632096000000                1632096000000
# 3                  1632096000000                1632096000000
# 10                 1632096000000                1632096000000
# 78                 1632096000000                1632096000000
# 98                 1632096000000                1632096000000
# 83                 1632096000000                1632096000000
# 40                 1632096000000                1632096000000
# 100                1632096000000                1632096000000
# 88                 1632096000000                1632096000000
# 94                 1632096000000                1632096000000
#
#     MCBU_GIS_DATA_MODIFIED_BY CURRENT_INDICATOR_LF MCBU_GIS_OPS_CONTACT  \
# 2        Janice Fisher (KCVL)                    Y        Matt Anderson
# 3        Janice Fisher (KCVL)                    Y        Matt Anderson
# 10       Janice Fisher (KCVL)                    Y        Matt Anderson
# 78       Janice Fisher (KCVL)                    Y     Darrell Carriger
# 98       Janice Fisher (KCVL)                    Y     Darrell Carriger
# 83       Janice Fisher (KCVL)                    Y     Darrell Carriger
# 40       Janice Fisher (KCVL)                    Y     Darrell Carriger
# 100      Janice Fisher (KCVL)                    Y     Darrell Carriger
# 88       Janice Fisher (KCVL)                    Y     Darrell Carriger
# 94       Janice Fisher (KCVL)                    Y     Darrell Carriger
#
#      SHAPE.STArea()  SHAPE.STLength()  \
# 2          0.001676          0.231572
# 3          0.002304          0.405253
# 10         0.005027          0.376302
# 78         0.001885          0.289470
# 98         0.000209          0.057894
# 83         0.000838          0.202629
# 40         0.000209          0.057893
# 100        0.000419          0.086840
# 88         0.001047          0.173680
# 94         0.000628          0.115787
#
#                                                  SHAPE
# 2    {"x": -11348081.4367, "y": 3714548.484099999, ...
# 3    {"x": -11358394.0743, "y": 3742121.344800003, ...
# 10   {"points": [[-11387672.2136, 3718989.142800003...
# 78   {"x": -11533260.2964, "y": 3766364.251000002, ...
# 98   {"points": [[-11585583.7967, 3785661.374300003...
# 83   {"x": -11578812.232, "y": 3794120.4617, "spati...
# 40   {"x": -11551202.7719, "y": 3795915.2677000016,...
# 100  {"points": [[-11539222.5683, 3795044.482699997...
# 88   {"x": -11551202.7719, "y": 3795915.2677000016,...
# 94   {"x": -11546255.7338, "y": 3796446.509300001, ...

# %%
# Publish layer as featurelayer
lyr = plumes_sedf_clipped.spatial.to_featurelayer(title='Plumes test', gis=gis)
lyr

#https://developers.arcgis.com/python/guide/introduction-to-the-spatially-enabled-dataframe/
#https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html
#https://community.esri.com/t5/python-questions/having-an-issue-where-the-nonetype-object-error-is/td-p/1086123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [85], in <module>
#       1 # Publish layer as featurelayer
# ----> 2 lyr = plumes_sedf_clipped.spatial.to_featurelayer(title='Plumes test', gis=gis)
#       3 lyr
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\features\geo\_accessor.py:2450, in GeoAccessor.to_featurelayer(self, title, gis, tags, folder)
#    2448         raise ValueError("GIS object must be provided")
#    2449 content = gis.content
# -> 2450 return content.import_data(self._data, folder=folder, title=title, tags=tags)
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\__init__.py:6462, in ContentManager.import_data(self, df, address_fields, folder, item_id, **kwargs)
#    6458     ds = df.spatial.to_featureclass(
#    6459         location=os.path.join(temp_dir, name)
#    6460     )
#    6461 zip_shp = zipws(path=temp_dir, outfile=temp_zip, keep=False)
# -> 6462 item = self.add(
#    6463     item_properties={"title": title, "tags": tags},
#    6464     data=zip_shp,
#    6465     folder=folder,
#    6466 )
#    6467 shutil.rmtree(temp_dir, ignore_errors=True)
#    6468 publish_parameters = {
#    6469     "hasStaticData": True,
#    6470     "name": os.path.splitext(item["name"])[0],
#    6471     "maxRecordCount": 2000,
#    6472     "layerInfo": {"capabilities": capabilities},
#    6473 }
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\__init__.py:5141, in ContentManager.add(self, item_properties, data, thumbnail, metadata, owner, folder, item_id, **kwargs)
#    5138     if filetype:
#    5139         item_properties["fileName"] = os.path.basename(data)
# -> 5141     itemid = self._portal.add_item(
#    5142         item_properties, data, thumbnail, metadata, owner_name, folder
#    5143     )
#    5145 if itemid is not None:
#    5146     item = Item(self._gis, itemid)
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\_impl\_portalpy.py:382, in Portal.add_item(self, item_properties, data, thumbnail, metadata, owner, folder)
#     380 # If owner isn't specified, use the logged in user
#     381 if not owner:
# --> 382     owner = self.logged_in_user()["username"]
#     384 # Setup the item path, including the folder, and post to it
#     385 path = "content/users/" + owner
#
# TypeError: 'NoneType' object is not subscriptable

# %%
gis
# Out:
# GIS @ https://maphub-amer.tst.azure.chevron.com/portal version:8.2

# %% [markdown]
# ## Plot data

# %%
# Plot location map
fig, (ax) = plt.subplots(1, 1, figsize=(15, 20))

xlim = ([plumes_gdf_clipped.total_bounds[0],
         plumes_gdf_clipped.total_bounds[2]])
ylim = ([plumes_gdf_clipped.total_bounds[1],
         plumes_gdf_clipped.total_bounds[3]])

ax.set_xlim(xlim)
ax.set_ylim(ylim)

fields_gdf.plot(ax=ax,
                color='None',
                edgecolor='black',
                linewidth=2)

plumes_gdf_clipped.plot(ax=ax,
                       color='red',
                       marker='*',
                       markersize=500,
                       linewidth=2
                       )

cx.add_basemap(ax, crs=fields_gdf.crs.to_string(),
               source=cx.providers.OpenStreetMap.Mapnik)

ax.set_title(
    "MCBU upstream fields", fontsize=20)

ax.set_axis_off()

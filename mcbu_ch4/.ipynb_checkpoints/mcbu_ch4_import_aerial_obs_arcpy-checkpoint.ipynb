# %% [markdown]
# # Import CH4 aerial observations data into unified database

# %% [markdown]
# ## Resources
# http://localhost:8888/notebooks/misc/arcgis-python-api/guide/04-feature-data-and-analysis/editing-features.ipynb
#
# https://developers.arcgis.com/python/guide/accessing-and-creating-content/
#
# http://localhost:8888/notebooks/misc/arcgis-python-api/samples/05_content_publishers/updating_features_in_a_feature_layer.ipynb

# %% [markdown]
# ## Import libraries and setup

# %%
import os
import datetime
import json
import shutil
from copy import deepcopy

import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import arcgis
from arcgis.gis import GIS
from arcgis.features import GeoAccessor
from arcgis import geometry #use geometry module to project Long,Lat to X and Y
#import contextily as cx

# %%
# Define layer id for aerial observations unified database
aerial_obs_layer_id = '8df1e448e7424ad09d2a8a1521267692'

# Define layer id for MCBU facilities dataset
facilities_layer_id = '857b2093bff44132b39e65176c309284'

# Define path to csv for new aerial observations
csv = 'MCBU_aerial_obs_3_24_2022.csv'

# %% [markdown]
# ## Function to load feature layer into GDF

# %%
def FeatureToGdf(feature_layer):
    """ Converts feature layer to geodataframe
    
    Parameters
    -----------
    feature_layer : ArcGIS API feature layer

    Returns
    -----------
    feature_gdf : geodataframe
    
    """
    import geopandas as gpd

    # .query() returns a FeatureSet
    fset = feature_layer.query()

    # get a GeoJSON string representation of the FeatureSet
    gjson_string = fset.to_geojson

    # read GeoJSON string into a dict
    gjson_dict = json.loads(gjson_string)

    # Read the dict into a gdf
    feature_gdf = gpd.GeoDataFrame.from_features(gjson_dict['features'])
    
    # Return GDF
    return feature_gdf

# %% [markdown]
# ## Connect to Chevron MapHub

# %%
gis = GIS("https://maphub-amer.tst.azure.chevron.com/portal", client_id='bb6vn14P957pN6bV')
print("Logged in as: " + gis.properties.user.username)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://maphub-amer.tst.azure.chevron.com/portal/sharing/rest//oauth2/authorize?response_type=code&client_id=bb6vn14P957pN6bV&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=NF7ZD0kMz55mwVAz6Sosu8ANIoqouP
# Enter code obtained on signing in using SAML: ········
# C:\Users\ekqo\Miniconda3\envs\arcgis\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'maphub-amer.tst.azure.chevron.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Logged in as: ekqo

# %% [markdown]
# ## Load CSV of new aerial observations

# %%
# Read csv into a df
aerial_obs_csv = pd.read_csv(csv)

# Read df into gdf and set crs
aerial_obs_gdf = gpd.GeoDataFrame(
    aerial_obs_csv, geometry=gpd.points_from_xy(aerial_obs_csv.obs_long, aerial_obs_csv.obs_lat))
aerial_obs_gdf = aerial_obs_gdf.set_crs(epsg=4267)
aerial_obs_gdf
# Out:
#       obs_id     obs_datetime  obs_lat  obs_long  obs_q obs_sensor  \
# 0    9Y84LZ6  2/18/2022 16:49  32.2987 -104.0665    230  GHGSat-C2
# 1  9XS28ET_1  2/10/2022 16:43  31.2719 -103.3187  2,766  GHGSat-C2
# 2  9XS28ET_2  2/10/2022 16:43  31.2720 -103.3115  1,421  GHGSat-C2
#
#                       geometry
# 0  POINT (-104.06650 32.29870)
# 1  POINT (-103.31870 31.27190)
# 2  POINT (-103.31150 31.27200)

# %% [markdown]
# ## Check aerial observations against unified database

# %%
# Load the aerial observations unified database from MapHub
aerial_obs_item = gis.content.get(aerial_obs_layer_id)
aerial_obs_layers = aerial_obs_item.layers
aerial_obs_fset = aerial_obs_layers[0].query()
aerial_obs_fset.sdf
# Out:
#    objectid fot_asset_name child_obj_code child_obj_desc  \
# 0         2           TEST           TEST           TEST
#
#     mcbu_gis_data_uploaded_date child_lat child_long   obs_id  \
# 0 2022-03-24 16:01:16.407000064      None       None  9Y84LZ6
#
#                    obs_datetime obs_lat obs_long  obs_q obs_sensor  \
# 0 2022-03-24 16:13:42.467000064    None     None  200.0     GHGSat
#
#                                                SHAPE
# 0  {"x": -11520140.3642, "y": 3681516.2709000036,...

# %%
# Select those rows in aerial_obs_csv that are not in aerial_obs_fset using obs_id field
new_rows_gdf = aerial_obs_gdf[~aerial_obs_gdf['obs_id'].isin(aerial_obs_fset.sdf['obs_id'])]
new_rows_gdf
# Out:
#       obs_id     obs_datetime  obs_lat  obs_long  obs_q obs_sensor  \
# 1  9XS28ET_1  2/10/2022 16:43  31.2719 -103.3187  2,766  GHGSat-C2
# 2  9XS28ET_2  2/10/2022 16:43  31.2720 -103.3115  1,421  GHGSat-C2
#
#                       geometry
# 1  POINT (-103.31870 31.27190)
# 2  POINT (-103.31150 31.27200)

# %% [markdown]
# ## Load new observations into unified database

# %% [markdown]
# ### Perform spatial join of new observations against MCBU facilities data

# %%
# Load the MCBU facilities data into a GDF
mcbu_facilities = gis.content.get(facilities_layer_id)

# Create blank list to store results
mcbu_facilities_list = []

# Iterate over the layers in the collection
for layer in mcbu_facilities.layers:

    # Check layer type to only process points
    if layer.properties.geometryType == 'esriGeometryPoint':
        
        # Convert the feature layer to a GDF
        facilities_gdf = FeatureToGdf(layer)

        # Append the gdf to the list
        mcbu_facilities_list.append(facilities_gdf)
        
    else:
        continue
    
# Combine all the df's into a single df for all the years
mcbu_facilities_gdf = pd.concat(mcbu_facilities_list, axis=0)

# Format the date fields as datetime
mcbu_facilities_gdf['MCBU_GIS_DATA_RECEIVED_DATE'] = pd.to_datetime(
    mcbu_facilities_gdf['MCBU_GIS_DATA_RECEIVED_DATE'], unit='ms')

mcbu_facilities_gdf['MCBU_GIS_DATA_UPLOADED_DATE'] = pd.to_datetime(
    mcbu_facilities_gdf['MCBU_GIS_DATA_UPLOADED_DATE'], unit='ms')

# Set the CRS
mcbu_facilities_gdf = mcbu_facilities_gdf.set_crs(epsg=4267)
#mcbu_facilities_gdf
# Out:
#                          geometry  OBJECTID    FOT_ASSET_NAME LOC_AREA  \
# 0     POINT (-103.51258 32.79950)  37697877  Buckeye / Vacuum  CENTRAL
# 1     POINT (-103.56483 32.81469)  37698013  Buckeye / Vacuum  CENTRAL
# 2     POINT (-103.50414 32.79431)  37698045  Buckeye / Vacuum  CENTRAL
# 3     POINT (-103.49062 32.79784)  37698096  Buckeye / Vacuum  CENTRAL
# 4     POINT (-103.30776 32.85134)  37698131  Buckeye / Vacuum  CENTRAL
# ...                           ...       ...               ...      ...
# 5868  POINT (-102.27396 31.73953)  37771187       Odessa West  MIDLAND
# 5869  POINT (-102.29058 31.70941)  37771190       Odessa West  MIDLAND
# 5870  POINT (-102.35241 31.70309)  37771195       Odessa West  MIDLAND
# 5871  POINT (-102.17613 31.89571)  37771200       Odessa West  MIDLAND
# 5872  POINT (-102.31811 31.75210)  37771208       Odessa West  MIDLAND
#
#       PARENT_OBJ_CODE PARENT_OBJ_CLASS                       PARENT_OBJ_DESC  \
# 0                 T49           OSEFLD                         FIELD; VACUUM
# 1                 T49           OSEFLD                         FIELD; VACUUM
# 2           BCT49CVUB           OSEBTY           BATTERY; CVU PRODUCTION BTY
# 3                 DY7           OSEFLD                   FIELD; VACUUM NORTH
# 4                 FA3           OSEFLD                      FIELD; LOVINGTON
# ...               ...              ...                                   ...
# 5868         PA8LCBBY           OSEBTY       BATTERY; LUPIN CENTRAL TANK BTY
# 5869  PA8LSTXLFEE37SB           OSEBTY     BATTERY; LUPIN TXL FEE SEC 37 SAT
# 5870         PA8LWEBY           OSEBTY  BATTERY; LUPIN WEST EDGE CENTRAL BTY
# 5871     PF8BGSEC28SB           OSEBTY          BATTERY; BRYANT G SEC 28 SAT
# 5872    QP8SALLIE23BY           OSEBTY                BATTERY; SALLIE 23 CTB
#
#      CHILD_OBJ_CODE CHILD_OBJ_CLASS                     CHILD_OBJ_DESC  ...  \
# 0       UCT49NOQBAB          OSEBTY              BATTERY; N O Q BA CTB  ...
# 1        UCT7NVAWUB          OSEBTY                 BATTERY; NVAWU BTY  ...
# 2        BCT49CVUIJ          OSEBTY  BATTERY; CVU INJECTION SYSTEM BTY  ...
# 3          DY7STABW          OSEBTY          BATTERY WELL; STATE A BTY  ...
# 4     FA3MDWYSTUBBW          OSEBTY     BATTERY; MIDWAY STATE UNIT BTY  ...
# ...             ...             ...                                ...  ...
# 5868         LZ4498           OSSWL          WELL; LUPIN TXL FEE 3101M  ...
# 5869         NC5541           OSSWL         WELL; LUPIN TXL FEE 3715ER  ...
# 5870         NN7903           OSSWL     WELL; LUPIN WE TXL FEE B 4113E  ...
# 5871         PC0968           OSSWL         WELL; C SCHARBAUER A 2805M  ...
# 5872         MU9896           OSSWL                 WELL; SALLIE 23 11  ...
#
#      TANK_COLOR BTU_RATE    HP TANK_ENG_SERVICE MCBU_GIS_DATA_UPLOADED_BY  \
# 0          None     None  None             None         svc-mcbu-gis-fmeT
# 1          None     None  None             None         svc-mcbu-gis-fmeT
# 2          None     None  None             None         svc-mcbu-gis-fmeT
# 3          None     None  None             None         svc-mcbu-gis-fmeT
# 4          None     None  None             None         svc-mcbu-gis-fmeT
# ...         ...      ...   ...              ...                       ...
# 5868       None     None  None             None         svc-mcbu-gis-fmeT
# 5869       None     None  None             None         svc-mcbu-gis-fmeT
# 5870       None     None  None             None         svc-mcbu-gis-fmeT
# 5871       None     None  None             None         svc-mcbu-gis-fmeT
# 5872       None     None  None             None         svc-mcbu-gis-fmeT
#
#      MCBU_GIS_DATA_SOURCE_NAME MCBU_GIS_DATA_SOURCE_TYPE  \
# 0                 FDS DATABASE               MS_SQL_VIEW
# 1                 FDS DATABASE               MS_SQL_VIEW
# 2                 FDS DATABASE               MS_SQL_VIEW
# 3                 FDS DATABASE               MS_SQL_VIEW
# 4                 FDS DATABASE               MS_SQL_VIEW
# ...                        ...                       ...
# 5868              FDS DATABASE               MS_SQL_VIEW
# 5869              FDS DATABASE               MS_SQL_VIEW
# 5870              FDS DATABASE               MS_SQL_VIEW
# 5871              FDS DATABASE               MS_SQL_VIEW
# 5872              FDS DATABASE               MS_SQL_VIEW
#
#      MCBU_GIS_DATA_REMARKS  MCBU_GIS_DATA_RECEIVED_DATE  \
# 0                                            2022-03-28
# 1                                            2022-03-28
# 2                                            2022-03-28
# 3                                            2022-03-28
# 4                                            2022-03-28
# ...                    ...                          ...
# 5868                                         2022-03-28
# 5869                                         2022-03-28
# 5870                                         2022-03-28
# 5871                                         2022-03-28
# 5872                                         2022-03-28
#
#       MCBU_GIS_DATA_UPLOADED_DATE
# 0                      2022-03-28
# 1                      2022-03-28
# 2                      2022-03-28
# 3                      2022-03-28
# 4                      2022-03-28
# ...                           ...
# 5868                   2022-03-28
# 5869                   2022-03-28
# 5870                   2022-03-28
# 5871                   2022-03-28
# 5872                   2022-03-28
#
# [7752 rows x 34 columns]

# %%
# Use spatial join to find nearest facility to each aerial observation
new_rows_joined_gdf = gpd.sjoin_nearest(new_rows_gdf, mcbu_facilities_gdf, how='inner', max_distance=0.01)
new_rows_joined_gdf.style
# Out:
# C:\Users\ekqo\Miniconda3\envs\arcgis\lib\site-packages\geopandas\array.py:341: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(
# <style type="text/css">
# </style>
# <table id="T_fc69c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc69c_level0_col0" class="col_heading level0 col0" >obs_id</th>
#       <th id="T_fc69c_level0_col1" class="col_heading level0 col1" >obs_datetime</th>
#       <th id="T_fc69c_level0_col2" class="col_heading level0 col2" >obs_lat</th>
#       <th id="T_fc69c_level0_col3" class="col_heading level0 col3" >obs_long</th>
#       <th id="T_fc69c_level0_col4" class="col_heading level0 col4" >obs_q</th>
#       <th id="T_fc69c_level0_col5" class="col_heading level0 col5" >obs_sensor</th>
#       <th id="T_fc69c_level0_col6" class="col_heading level0 col6" >geometry</th>
#       <th id="T_fc69c_level0_col7" class="col_heading level0 col7" >index_right</th>
#       <th id="T_fc69c_level0_col8" class="col_heading level0 col8" >OBJECTID</th>
#       <th id="T_fc69c_level0_col9" class="col_heading level0 col9" >FOT_ASSET_NAME</th>
#       <th id="T_fc69c_level0_col10" class="col_heading level0 col10" >LOC_AREA</th>
#       <th id="T_fc69c_level0_col11" class="col_heading level0 col11" >PARENT_OBJ_CODE</th>
#       <th id="T_fc69c_level0_col12" class="col_heading level0 col12" >PARENT_OBJ_CLASS</th>
#       <th id="T_fc69c_level0_col13" class="col_heading level0 col13" >PARENT_OBJ_DESC</th>
#       <th id="T_fc69c_level0_col14" class="col_heading level0 col14" >CHILD_OBJ_CODE</th>
#       <th id="T_fc69c_level0_col15" class="col_heading level0 col15" >CHILD_OBJ_CLASS</th>
#       <th id="T_fc69c_level0_col16" class="col_heading level0 col16" >CHILD_OBJ_DESC</th>
#       <th id="T_fc69c_level0_col17" class="col_heading level0 col17" >CHILD_CLASS_ALIAS_NAME</th>
#       <th id="T_fc69c_level0_col18" class="col_heading level0 col18" >CHILD_COST_CODE</th>
#       <th id="T_fc69c_level0_col19" class="col_heading level0 col19" >CHILD_COST_DESC</th>
#       <th id="T_fc69c_level0_col20" class="col_heading level0 col20" >CHILD_MANUFACT_MODEL</th>
#       <th id="T_fc69c_level0_col21" class="col_heading level0 col21" >CHILD_SERIAL_NUMBER</th>
#       <th id="T_fc69c_level0_col22" class="col_heading level0 col22" >CHILD_STATUS</th>
#       <th id="T_fc69c_level0_col23" class="col_heading level0 col23" >CHILD_CRITICALITY</th>
#       <th id="T_fc69c_level0_col24" class="col_heading level0 col24" >IC_CUSTOM</th>
#       <th id="T_fc69c_level0_col25" class="col_heading level0 col25" >CHILD_COMMISS</th>
#       <th id="T_fc69c_level0_col26" class="col_heading level0 col26" >CHILD_LAT</th>
#       <th id="T_fc69c_level0_col27" class="col_heading level0 col27" >CHILD_LONG</th>
#       <th id="T_fc69c_level0_col28" class="col_heading level0 col28" >TANK_SIZE</th>
#       <th id="T_fc69c_level0_col29" class="col_heading level0 col29" >TANK_SERVICE</th>
#       <th id="T_fc69c_level0_col30" class="col_heading level0 col30" >TANK_CONTENTS</th>
#       <th id="T_fc69c_level0_col31" class="col_heading level0 col31" >TANK_COLOR</th>
#       <th id="T_fc69c_level0_col32" class="col_heading level0 col32" >BTU_RATE</th>
#       <th id="T_fc69c_level0_col33" class="col_heading level0 col33" >HP</th>
#       <th id="T_fc69c_level0_col34" class="col_heading level0 col34" >TANK_ENG_SERVICE</th>
#       <th id="T_fc69c_level0_col35" class="col_heading level0 col35" >MCBU_GIS_DATA_UPLOADED_BY</th>
#       <th id="T_fc69c_level0_col36" class="col_heading level0 col36" >MCBU_GIS_DATA_SOURCE_NAME</th>
#       <th id="T_fc69c_level0_col37" class="col_heading level0 col37" >MCBU_GIS_DATA_SOURCE_TYPE</th>
#       <th id="T_fc69c_level0_col38" class="col_heading level0 col38" >MCBU_GIS_DATA_REMARKS</th>
#       <th id="T_fc69c_level0_col39" class="col_heading level0 col39" >MCBU_GIS_DATA_RECEIVED_DATE</th>
#       <th id="T_fc69c_level0_col40" class="col_heading level0 col40" >MCBU_GIS_DATA_UPLOADED_DATE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc69c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fc69c_row0_col0" class="data row0 col0" >9XS28ET_1</td>
#       <td id="T_fc69c_row0_col1" class="data row0 col1" >2/10/2022 16:43</td>
#       <td id="T_fc69c_row0_col2" class="data row0 col2" >31.271900</td>
#       <td id="T_fc69c_row0_col3" class="data row0 col3" >-103.318700</td>
#       <td id="T_fc69c_row0_col4" class="data row0 col4" >2,766</td>
#       <td id="T_fc69c_row0_col5" class="data row0 col5" >GHGSat-C2</td>
#       <td id="T_fc69c_row0_col6" class="data row0 col6" >POINT (-103.3187 31.2719)</td>
#       <td id="T_fc69c_row0_col7" class="data row0 col7" >281</td>
#       <td id="T_fc69c_row0_col8" class="data row0 col8" >37724632</td>
#       <td id="T_fc69c_row0_col9" class="data row0 col9" >Ft. Stockton</td>
#       <td id="T_fc69c_row0_col10" class="data row0 col10" >CENTRAL</td>
#       <td id="T_fc69c_row0_col11" class="data row0 col11" >QV2</td>
#       <td id="T_fc69c_row0_col12" class="data row0 col12" >OSEFLD</td>
#       <td id="T_fc69c_row0_col13" class="data row0 col13" >FIELD; WOLFBONE</td>
#       <td id="T_fc69c_row0_col14" class="data row0 col14" >QV2WLFBN1BTY</td>
#       <td id="T_fc69c_row0_col15" class="data row0 col15" >OSEBTY</td>
#       <td id="T_fc69c_row0_col16" class="data row0 col16" >BATTERY; WOLFBONE 1 CTB (AKA REEVES TXL 1 BTY)</td>
#       <td id="T_fc69c_row0_col17" class="data row0 col17" >SE - Battery</td>
#       <td id="T_fc69c_row0_col18" class="data row0 col18" >UCQV2J01X</td>
#       <td id="T_fc69c_row0_col19" class="data row0 col19" >DB WB REEVES TXL FEE CTB SC 9 15 3 27 21</td>
#       <td id="T_fc69c_row0_col20" class="data row0 col20" >NONE</td>
#       <td id="T_fc69c_row0_col21" class="data row0 col21" >NONE</td>
#       <td id="T_fc69c_row0_col22" class="data row0 col22" >I</td>
#       <td id="T_fc69c_row0_col23" class="data row0 col23" >NA</td>
#       <td id="T_fc69c_row0_col24" class="data row0 col24" >None</td>
#       <td id="T_fc69c_row0_col25" class="data row0 col25" >1407801600000</td>
#       <td id="T_fc69c_row0_col26" class="data row0 col26" >31.271452</td>
#       <td id="T_fc69c_row0_col27" class="data row0 col27" >-103.318574</td>
#       <td id="T_fc69c_row0_col28" class="data row0 col28" >None</td>
#       <td id="T_fc69c_row0_col29" class="data row0 col29" >None</td>
#       <td id="T_fc69c_row0_col30" class="data row0 col30" >None</td>
#       <td id="T_fc69c_row0_col31" class="data row0 col31" >None</td>
#       <td id="T_fc69c_row0_col32" class="data row0 col32" >None</td>
#       <td id="T_fc69c_row0_col33" class="data row0 col33" >None</td>
#       <td id="T_fc69c_row0_col34" class="data row0 col34" >None</td>
#       <td id="T_fc69c_row0_col35" class="data row0 col35" >svc-mcbu-gis-fmeT</td>
#       <td id="T_fc69c_row0_col36" class="data row0 col36" >FDS DATABASE</td>
#       <td id="T_fc69c_row0_col37" class="data row0 col37" >MS_SQL_VIEW</td>
#       <td id="T_fc69c_row0_col38" class="data row0 col38" ></td>
#       <td id="T_fc69c_row0_col39" class="data row0 col39" >2022-03-28 00:00:00</td>
#       <td id="T_fc69c_row0_col40" class="data row0 col40" >2022-03-28 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_fc69c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fc69c_row1_col0" class="data row1 col0" >9XS28ET_2</td>
#       <td id="T_fc69c_row1_col1" class="data row1 col1" >2/10/2022 16:43</td>
#       <td id="T_fc69c_row1_col2" class="data row1 col2" >31.272000</td>
#       <td id="T_fc69c_row1_col3" class="data row1 col3" >-103.311500</td>
#       <td id="T_fc69c_row1_col4" class="data row1 col4" >1,421</td>
#       <td id="T_fc69c_row1_col5" class="data row1 col5" >GHGSat-C2</td>
#       <td id="T_fc69c_row1_col6" class="data row1 col6" >POINT (-103.3115 31.272)</td>
#       <td id="T_fc69c_row1_col7" class="data row1 col7" >389</td>
#       <td id="T_fc69c_row1_col8" class="data row1 col8" >37738252</td>
#       <td id="T_fc69c_row1_col9" class="data row1 col9" >Ft. Stockton</td>
#       <td id="T_fc69c_row1_col10" class="data row1 col10" >CENTRAL</td>
#       <td id="T_fc69c_row1_col11" class="data row1 col11" >QV2</td>
#       <td id="T_fc69c_row1_col12" class="data row1 col12" >OSEFLD</td>

# %% [markdown]
# ### Create features from new rows

# %%
# Get an example feature
features_for_update = aerial_obs_fset.features[0]

# Get a template feature object
template_feature = deepcopy(features_for_update)

# List of features to be added
features_to_be_added = []

# loop through each row and add to the list of features to be added
for row in new_rows_joined_gdf.iterrows():
    new_feature = deepcopy(template_feature)

    # print
    print("Creating entry for obs_id: " + row[1]['obs_id'])

    # get geometries in the destination coordinate system
    input_geometry = {'y': float(row[1]['CHILD_LAT']),
                      'x': float(row[1]['CHILD_LONG'])}
    output_geometry = geometry.project(geometries=[input_geometry],
                                       in_sr=new_rows_joined_gdf.crs,
                                       out_sr=aerial_obs_fset.spatial_reference['latestWkid'],
                                       gis=gis)
# Out:
# Creating entry for obs_id: 9XS28ET_1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\_impl\tools.py:330, in _GISService.__init__(self, url, gis)
#     329 try:
# --> 330     self._token = self._con.generate_portal_server_token(url)
#     331 except Exception as e:  # GUESSED Auth Wrong, try anonymously
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1795, in Connection.generate_portal_server_token(self, serverUrl, expiration)
#    1794 else:
# -> 1795     resp = self.post(
#    1796         path=self._token_url, postdata=postdata, ssl=True, add_token=False
#    1797     )
#    1798 if isinstance(resp, dict) and resp:
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1074, in Connection.post(self, path, params, files, **kwargs)
#    1073 retry_count = 0
# -> 1074 return self._handle_response(
#    1075     resp=resp,
#    1076     out_path=out_path,
#    1077     file_name=file_name,
#    1078     try_json=try_json,
#    1079     force_bytes=kwargs.pop("force_bytes", False),
#    1080 )
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:625, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     624     errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 625     self._handle_json_error(data["error"], errorcode)
#     626 return data
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:648, in Connection._handle_json_error(self, error, errorcode)
#     647 errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 648 raise Exception(errormessage)
#
# Exception: client_id not specified
# (Error Code: 400)
#
# During handling of the above exception, another exception occurred:
#
# RequestException                          Traceback (most recent call last)
# Input In [46], in <module>
#      17 # get geometries in the destination coordinate system
#      18 input_geometry = {'y': float(row[1]['CHILD_LAT']),
#      19                   'x': float(row[1]['CHILD_LONG'])}
# ---> 20 output_geometry = geometry.project(geometries=[input_geometry],
#      21                                    in_sr=new_rows_joined_gdf.crs,
#      22                                    out_sr=aerial_obs_fset.spatial_reference['latestWkid'],
#      23                                    gis=gis)
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\geometry\functions.py:1025, in project(geometries, in_sr, out_sr, transformation, transform_forward, gis, future)
#    1023 if gis is None:
#    1024     gis = arcgis.env.active_gis
# -> 1025 return gis._tools.geometry.project(
#    1026     geometries, in_sr, out_sr, transformation, transform_forward, future=future
#    1027 )
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\_impl\tools.py:17307, in _Tools.geometry(self)
#   17305     else:
#   17306         svcurl = self._gis.properties["helperServices"]["geometry"]["url"]
# > 17307     self._geometry = _GeometryService(svcurl, self._gis)
#   17308     return self._geometry
#   17309 except KeyError:
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\_impl\tools.py:15619, in _GeometryService.__init__(self, url, gis)
#   15618 def __init__(self, url, gis=None):
# > 15619     super(_GeometryService, self).__init__(url, gis)
#
# File ~\Miniconda3\envs\arcgis\lib\site-packages\arcgis\_impl\tools.py:354, in _GISService.__init__(self, url, gis)
#     351         else:
#     352             from requests.exceptions import RequestException
# --> 354             raise RequestException(str(e))
#     355 else:
#     356     self._token = self._con.token
#
# RequestException: client_id not specified
# (Error Code: 400)

# %%
# Loop over the rows to populate featureset

# %%
# Get data
mcbu_facilities = gis.content.get(facilities_layer_id)

# Create blank list to store results
mcbu_facilities_list = []

# Iterate over the layers in the collection
for layer in mcbu_facilities.layers:

    # Check layer type to only process points
    if layer.properties.geometryType == 'esriGeometryPoint':
        
        # Convert the feature layer to a GDF
        facilities_gdf = FeatureToGdf(layer)

        # Append the gdf to the list
        mcbu_facilities_list.append(facilities_gdf)
        
    else:
        continue
    
# Combine all the df's into a single df for all the years
mcbu_facilities_df = pd.concat(mcbu_facilities_list, axis=0)

# Format the date fields as datetime
mcbu_facilities_df['MCBU_GIS_DATA_RECEIVED_DATE'] = pd.to_datetime(
    mcbu_facilities_df['MCBU_GIS_DATA_RECEIVED_DATE'], unit='ms')

mcbu_facilities_df['MCBU_GIS_DATA_UPLOADED_DATE'] = pd.to_datetime(
    mcbu_facilities_df['MCBU_GIS_DATA_UPLOADED_DATE'], unit='ms')

# Set the CRS
mcbu_facilities_df = mcbu_facilities_df.set_crs(epsg=4267)
mcbu_facilities_df

# %% [markdown]
# ## Load the MCBU_CH4_aerial_obs feature layer
